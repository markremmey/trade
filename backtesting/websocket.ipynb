# %%
from alpaca.data.live import CryptoDataStream
from talipp.indicators import EMA, ATR
from datetime import datetime
from dotenv import load_dotenv
import os

# %%
import talipp
help(talipp.indicators)
# Out:
# Help on package talipp.indicators in talipp:
#
# NAME
#     talipp.indicators
#
# PACKAGE CONTENTS
#     ADX
#     ALMA
#     AO
#     ATR
#     AccuDist
#     Aroon
#     BB
#     BOP
#     CCI
#     CHOP
#     ChaikinOsc
#     ChandeKrollStop
#     CoppockCurve
#     DEMA
#     DPO
#     DonchianChannels
#     EMA
#     EMV
#     FibRetracement
#     ForceIndex
#     HMA
#     Ichimoku
#     Indicator
#     KAMA
#     KST
#     KVO
#     KeltnerChannels
#     MACD
#     MassIndex
#     McGinleyDynamic
#     MeanDev
#     OBV
#     ParabolicSAR
#     PivotsHL
#     ROC
#     RSI
#     SFX
#     SMA
#     SMMA
#     SOBV
#     StdDev
#     Stoch
#     StochRSI
#     SuperTrend
#     TEMA
#     TRIX
#     TSI
#     TTM
#     UO
#     VTX
#     VWAP
#     VWMA
#     WMA
#
# CLASSES
#     builtins.object
#         talipp.indicators.FibRetracement.FibRetracement
#     talipp.indicators.Indicator.Indicator(collections.abc.Sequence)
#         talipp.indicators.ADX.ADX
# ...

# %%
help(EMA)
# Out:
# Help on class EMA in module talipp.indicators.EMA:
#
# class EMA(talipp.indicators.Indicator.Indicator)
#  |  EMA(period: int, input_values: List[float] = None, input_indicator: talipp.indicators.Indicator.Indicator = None, value_extractor: Callable[..., Any] = None)
#  |
#  |  Exponential Moving Average
#  |
#  |  Output: a list of floats
#  |
#  |  Method resolution order:
#  |      EMA
#  |      talipp.indicators.Indicator.Indicator
#  |      collections.abc.Sequence
#  |      collections.abc.Reversible
#  |      collections.abc.Collection
#  |      collections.abc.Sized
#  |      collections.abc.Iterable
#  |      collections.abc.Container
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, period: int, input_values: List[float] = None, input_indicator: talipp.indicators.Indicator.Indicator = None, value_extractor: Callable[..., Any] = None)
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
# ...
